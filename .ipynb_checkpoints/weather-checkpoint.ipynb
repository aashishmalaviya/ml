# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\mldata\weather\weather.csv")

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.shape
# Out:
# (366, 22)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
data.WindGustDir.unique
# Out:
# <bound method Series.unique of 0       NW
# 1      ENE
# 2       NW
# 3       NW
# 4      SSE
#       ...
# 361    NNW
# 362      N
# 363    ESE
# 364     NW
# 365     NW
# Name: WindGustDir, Length: 366, dtype: object>

# %%
data['WindGustDir'].unique()
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
data.nunique
# Out:
# <bound method DataFrame.nunique of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
data['WindGustDir'].unique
# Out:
# <bound method Series.unique of 0       NW
# 1      ENE
# 2       NW
# 3       NW
# 4      SSE
#       ...
# 361    NNW
# 362      N
# 363    ESE
# 364     NW
# 365     NW
# Name: WindGustDir, Length: 366, dtype: object>

# %%
data['WindGustDir'].nunique()
# Out:
# 16

# %%
data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
#Gives complete count of all columns without Nulls
data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
data['WindGustDir'].value_counts()
# Out:
# WindGustDir
# NW     73
# NNW    44
# E      37
# WNW    35
# ENE    30
# ESE    23
# S      22
# N      21
# W      20
# NE     16
# SSE    12
# SE     12
# NNE     8
# SSW     5
# SW      3
# WSW     2
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
data['WindGustDir'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['WindGustDir'].unique()
#
# NameError: name 'data' is not defined

# %%
data['WindGustDir'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data['WindGustDir'].unique()
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data['WindGustDir'].unique()
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data['WindGustDir'] == 'N'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362     True
# 363    False
# 364    False
# 365    False
# Name: WindGustDir, Length: 366, dtype: bool

# %%
data[data['WindGustDir'] == 'N']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 10       9.1     25.2       0.0          4.2      11.9           N
# 50      14.8     29.5       6.4          1.8       8.1           N
# 76      17.9     33.2       0.0         10.4       8.4           N
# 147      4.4     18.3       0.0          4.6       9.6           N
# 155      0.4     18.9       0.0          4.8       9.6           N
# 181     -1.8     14.8       0.0          1.4       7.0           N
# 230      0.4     15.5       0.0          1.0       4.7           N
# 245     -1.6     11.5       0.0          2.8       8.9           N
# 254     -2.6     11.1       0.2          1.4       6.5           N
# 258     -0.9     12.8       0.2          2.0       1.9           N
# 281      3.1     12.5       1.2          1.4       7.2           N
# 284     -0.3      9.3       0.4          1.4       9.9           N
# 290     -1.3     11.6       0.0          4.0      10.4           N
# ...

# %%
data.groupby('WindGustDir').get_group('N')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 10       9.1     25.2       0.0          4.2      11.9           N
# 50      14.8     29.5       6.4          1.8       8.1           N
# 76      17.9     33.2       0.0         10.4       8.4           N
# 147      4.4     18.3       0.0          4.6       9.6           N
# 155      0.4     18.9       0.0          4.8       9.6           N
# 181     -1.8     14.8       0.0          1.4       7.0           N
# 230      0.4     15.5       0.0          1.0       4.7           N
# 245     -1.6     11.5       0.0          2.8       8.9           N
# 254     -2.6     11.1       0.2          1.4       6.5           N
# 258     -0.9     12.8       0.2          2.0       1.9           N
# 281      3.1     12.5       1.2          1.4       7.2           N
# 284     -0.3      9.3       0.4          1.4       9.9           N
# 290     -1.3     11.6       0.0          4.0      10.4           N
# ...

# %%
data.groupby('WindGustDir').get_group('NNW')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 29      13.6     24.1       0.4          2.6       0.5         NNW
# 39      14.9     24.8       0.0         10.4      10.0         NNW
# 49      12.6     23.1       3.4          1.6       2.3         NNW
# 51      19.9     22.0      11.0          4.4       5.9         NNW
# 55       9.8     26.3       0.0          5.2      13.0         NNW
# 56      14.3     26.7       0.0          7.2       7.1         NNW
# 57      15.1     28.3      14.4          8.8      13.2         NNW
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 88      15.3     33.2       0.0          9.4      13.2         NNW
# 128      9.5     27.4       3.0          4.8      11.5         NNW
# 145     13.1     17.4       6.4          2.8       0.0         NNW
# 152      3.5     21.8       0.0          6.0      10.3         NNW
# 153      5.3     23.3       0.0          3.6       5.6         NNW
# ...

# %%
data[data['WindGustSpeed'] == 30.0]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 10       9.1     25.2       0.0          4.2      11.9           N
# 12      10.1     27.9       0.0          7.2      13.0         WNW
# 29      13.6     24.1       0.4          2.6       0.5         NNW
# 49      12.6     23.1       3.4          1.6       2.3         NNW
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 92      16.0     23.8       2.2          5.4       6.2         SSE
# 93      14.9     28.8       0.0          5.8       8.1         NNE
# 96      16.8     22.8       9.0          2.8       0.3         ESE
# 104     12.6     18.2      11.0          3.2       0.4         ENE
# 141     13.0     14.8       0.0          8.2       0.0          SE
# 143     12.8     24.9       0.0          2.4       6.2         ENE
# 172      2.4     20.6       0.0          2.8      10.1           E
# ...

# %%
# find null values in data frame
data.isnull()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
# find null values in data frame summarized
data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
# find not null values in data frame summarized
data.notnull().sum()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
# rename a column name for this command only
data.rename(columns = {'Sunshine' : 'Clear'})
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Clear WindGustDir  \
# 0        8.0     24.3       0.0          3.4    6.3          NW
# 1       14.0     26.9       3.6          4.4    9.7         ENE
# 2       13.7     23.4       3.6          5.8    3.3          NW
# 3       13.3     15.5      39.8          7.2    9.1          NW
# 4        7.6     16.1       2.8          5.6   10.6         SSE
# ..       ...      ...       ...          ...    ...         ...
# 361      9.0     30.7       0.0          7.6   12.1         NNW
# 362      7.1     28.4       0.0         11.6   12.7           N
# 363     12.5     19.9       0.0          8.4    5.3         ESE
# 364     12.5     26.9       0.0          5.0    7.1          NW
# 365     12.3     30.2       0.0          6.0   12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
#column comes back if we access data

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
# rename a column name permanently
data.rename(columns = {'Sunshine' : 'Clear'}, inplace = True)

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Clear WindGustDir  WindGustSpeed  \
# 0      8.0     24.3       0.0          3.4    6.3          NW           30.0
# 1     14.0     26.9       3.6          4.4    9.7         ENE           39.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  Pressure9am  \
# 0         SW         NW           6.0  ...           29       1019.7
# 1          E          W           4.0  ...           36       1012.4
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1015.0         7         7     14.4     23.6         No      3.6
# 1       1008.4         5         3     17.5     25.7        Yes      3.6
#
#   RainTomorrow
# 0          Yes
# 1          Yes
#
# [2 rows x 22 columns]

# %%
#finding mean of a column of say Evaporation

# %%
data.Evaporation.mean()
# Out:
# 4.521857923497268

# %%
#find std deviation

# %%
data.Evaporation.std()
# Out:
# 2.6693825342212643

# %%
#find variance
data['Evaporation'].var()
# Out:
# 7.12560311400554
